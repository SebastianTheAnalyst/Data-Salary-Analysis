# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/sebastiangurgel/Desktop/Github/Data Salery Analysis'

# %%
data = pd.read_csv("ds_salaries.csv")

# %%
data.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...

# %%
data.shape
# Out:
# (607, 12)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
data.work_year.unique()
# Out:
# array([2020, 2021, 2022])

# %%
df=data[[ 'work_year', 'experience_level', 'employment_type',
       'job_title','salary_currency', 'salary_in_usd',
       'employee_residence', 'company_location' ]].copy()
#'company_size'
#'remote_ratio'
#'salary'
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
# ...

# %%
df.shape
# Out:
# (607, 8)

# %%
df.rename(columns={"work_year":"year","experience_level":"experience","employment_type":"employment"})
# Out:
#      year experience employment                   job_title salary_currency  \
# 0    2020         MI         FT              Data Scientist             EUR
# 1    2020         SE         FT  Machine Learning Scientist             USD
# 2    2020         SE         FT           Big Data Engineer             GBP
# 3    2020         MI         FT        Product Data Analyst             USD
# 4    2020         SE         FT   Machine Learning Engineer             USD
# ..    ...        ...        ...                         ...             ...
# 602  2022         SE         FT               Data Engineer             USD
# 603  2022         SE         FT               Data Engineer             USD
# 604  2022         SE         FT                Data Analyst             USD
# 605  2022         SE         FT                Data Analyst             USD
# 606  2022         MI         FT                AI Scientist             USD
#
#      salary_in_usd employee_residence company_location
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#   salary_currency  salary_in_usd employee_residence company_location
# 0             EUR          79833                 DE               DE
# 1             USD         260000                 JP               JP
# 2             GBP         109024                 GB               GB
# 3             USD          20000                 HN               HN
# 4             USD         150000                 US               US

# %%
df.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# company_location      0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 602    False
# 603    False
# 604    False
# 605    False
# 606    False
# Length: 607, dtype: bool

# %%
ax=df["job_title"].value_counts().head(10).plot(kind="barh", title="Data Jobs 2020-2022")
ax.set_xlabel("Häufigkeit")
ax.set_ylabel("Berufsbezeichnung")
ax.grid("grey")

# %%
df.job_title.unique()
# Out:
# array(['Data Scientist', 'Machine Learning Scientist',
#        'Big Data Engineer', 'Product Data Analyst',
#        'Machine Learning Engineer', 'Data Analyst', 'Lead Data Scientist',
#        'Business Data Analyst', 'Lead Data Engineer', 'Lead Data Analyst',
#        'Data Engineer', 'Data Science Consultant', 'BI Data Analyst',
#        'Director of Data Science', 'Research Scientist',
#        'Machine Learning Manager', 'Data Engineering Manager',
#        'Machine Learning Infrastructure Engineer', 'ML Engineer',
#        'AI Scientist', 'Computer Vision Engineer',
#        'Principal Data Scientist', 'Data Science Manager', 'Head of Data',
#        '3D Computer Vision Researcher', 'Data Analytics Engineer',
#        'Applied Data Scientist', 'Marketing Data Analyst',
#        'Cloud Data Engineer', 'Financial Data Analyst',
#        'Computer Vision Software Engineer',
#        'Director of Data Engineering', 'Data Science Engineer',
# ...

# %%
filt = df["job_title"].str.contains("Data Analyst")
df.loc[filt]
# Out:
#      work_year experience_level employment_type              job_title  \
# 3         2020               MI              FT   Product Data Analyst
# 5         2020               EN              FT           Data Analyst
# 8         2020               MI              FT  Business Data Analyst
# 13        2020               MI              FT      Lead Data Analyst
# 14        2020               MI              FT           Data Analyst
# ..         ...              ...             ...                    ...
# 597       2022               SE              FT           Data Analyst
# 600       2022               EN              FT           Data Analyst
# 601       2022               EN              FT           Data Analyst
# 604       2022               SE              FT           Data Analyst
# 605       2022               SE              FT           Data Analyst
#
#     salary_currency  salary_in_usd employee_residence company_location
# ...

# %%
df.sort_values(by="salary_in_usd", ascending=False).head(5)
# Out:
#      work_year experience_level employment_type  \
# 252       2021               EX              FT
# 97        2021               MI              FT
# 33        2020               MI              FT
# 157       2021               MI              FT
# 225       2021               EX              CT
#
#                               job_title salary_currency  salary_in_usd  \
# 252             Principal Data Engineer             USD         600000
# 97               Financial Data Analyst             USD         450000
# 33                   Research Scientist             USD         450000
# 157  Applied Machine Learning Scientist             USD         423000
# 225            Principal Data Scientist             USD         416000
#
#     employee_residence company_location
# 252                 US               US
# 97                  US               US
# 33                  US               US
# 157                 US               US
# 225                 US               US

# %%
df.sort_values(by=["job_title","salary_in_usd"], ascending=[True, False]).head()
# Out:
#      work_year experience_level employment_type  \
# 77        2021               MI              PT
# 606       2022               MI              FT
# 391       2022               MI              FT
# 277       2021               SE              FT
# 52        2020               EN              FT
#
#                          job_title salary_currency  salary_in_usd  \
# 77   3D Computer Vision Researcher             INR           5409
# 606                   AI Scientist             USD         200000
# 391                   AI Scientist             USD         120000
# 277                   AI Scientist             USD          55000
# 52                    AI Scientist             DKK          45896
#
#     employee_residence company_location
# 77                  IN               IN
# 606                 IN               US
# 391                 US               US
# 277                 ES               ES
# 52                  DK               DK

# %%
df.sort_values(by=["company_location","salary_in_usd"], ascending=[True, False]).head()
# Out:
#      work_year experience_level employment_type                  job_title  \
# 480       2022               SE              FT  Machine Learning Engineer
# 24        2020               MI              FT        Lead Data Scientist
# 481       2022               SE              FT  Machine Learning Engineer
# 244       2021               EN              FT               AI Scientist
# 69        2020               SE              FT             Data Scientist
#
#     salary_currency  salary_in_usd employee_residence company_location
# 480             USD         120000                 AE               AE
# 24              USD         115000                 AE               AE
# 481             USD          65000                 AE               AE
# 244             INR          18053                 IN               AS
# 69              EUR          91237                 AT               AT

# %%
df.nlargest(3,"salary_in_usd")
# Out:
#      work_year experience_level employment_type                job_title  \
# 252       2021               EX              FT  Principal Data Engineer
# 33        2020               MI              FT       Research Scientist
# 97        2021               MI              FT   Financial Data Analyst
#
#     salary_currency  salary_in_usd employee_residence company_location
# 252             USD         600000                 US               US
# 33              USD         450000                 US               US
# 97              USD         450000                 US               US

# %%
df["job_title"].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
country_grp = df.groupby(["company_location"])

# %%
country_grp.get_group("DE").head()
# Out:
#     work_year experience_level employment_type                 job_title  \
# 0        2020               MI              FT            Data Scientist
# 30       2020               MI              FT  Data Engineering Manager
# 45       2020               EN              PT               ML Engineer
# 53       2020               EN              FT             Data Engineer
# 55       2020               SE              FT  Principal Data Scientist
#
#    salary_currency  salary_in_usd employee_residence company_location
# 0              EUR          79833                 DE               DE
# 30             EUR          59303                 DE               DE
# 45             EUR          15966                 DE               DE
# 53             EUR          54742                 PK               DE
# 55             EUR         148261                 DE               DE

# %%
df.company_location.unique()
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'CN',
#        'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'ES', 'PT', 'DK', 'IT',
#        'HR', 'LU', 'PL', 'SG', 'RO', 'IQ', 'BR', 'BE', 'UA', 'IL', 'RU',
#        'MT', 'CL', 'IR', 'CO', 'MD', 'KE', 'SI', 'CH', 'VN', 'AS', 'TR',
#        'CZ', 'DZ', 'EE', 'MY', 'AU', 'IE'], dtype=object)

# %%
filt=df["company_location"]=="DE"
df.loc[filt].head(10)
# Out:
#      work_year experience_level employment_type                  job_title  \
# 0         2020               MI              FT             Data Scientist
# 30        2020               MI              FT   Data Engineering Manager
# 45        2020               EN              PT                ML Engineer
# 53        2020               EN              FT              Data Engineer
# 55        2020               SE              FT   Principal Data Scientist
# 65        2020               EN              FT             Data Scientist
# 66        2020               EN              FT             Data Scientist
# 80        2021               SE              FT    Data Analytics Engineer
# 91        2021               EN              FT    Data Science Consultant
# 110       2021               SE              FT  Machine Learning Engineer
#
#     salary_currency  salary_in_usd employee_residence company_location
# 0               EUR          79833                 DE               DE
# ...

# %%
country_grp["job_title"].value_counts().head(20)
# Out:
# company_location  job_title
# AE                Machine Learning Engineer            2
#                   Lead Data Scientist                  1
# AS                AI Scientist                         1
# AT                Data Scientist                       2
#                   Data Engineer                        1
#                   Research Scientist                   1
# AU                Computer Vision Software Engineer    1
#                   Data Scientist                       1
#                   Machine Learning Engineer            1
# BE                Machine Learning Engineer            2
# BR                Computer Vision Engineer             2
#                   Data Scientist                       1
# CA                Data Analyst                         9
#                   Data Scientist                       5
#                   Research Scientist                   3
#                   Data Architect                       2
# ...

# %%
country_grp["job_title"].value_counts().loc["DE"]
# Out:
# job_title
# Data Scientist                    7
# Data Engineer                     4
# Machine Learning Engineer         4
# Data Science Consultant           3
# Principal Data Scientist          3
# Director of Data Science          2
# Data Analyst                      1
# Data Analytics Engineer           1
# Data Engineering Manager          1
# Lead Machine Learning Engineer    1
# ML Engineer                       1
# Name: job_title, dtype: int64

# %%
country_grp["salary_in_usd"].median().head(10)
# Out:
# company_location
# AE    115000.0
# AS     18053.0
# AT     69489.5
# AU     87425.0
# BE     85699.0
# BR     18907.0
# CA     81895.5
# CH     64114.0
# CL     40038.0
# CN     71665.5
# Name: salary_in_usd, dtype: float64

# %%
country_grp["salary_in_usd"].median().loc["DE"]
# Out:
# 78015.0

# %%
filt=df["company_location"]=="DE"
df.loc[filt]["job_title"].str.contains("Data Analyst").sum()
# Out:
# 1

# %%
 country_grp["job_title"].apply(lambda x: x.str.contains("Data Analyst").sum())
# Out:
# company_location
# AE     0
# AS     0
# AT     0
# AU     0
# BE     0
# BR     0
# CA    11
# CH     0
# CL     0
# CN     0
# CO     0
# CZ     0
# DE     1
# DK     1
# DZ     0
# EE     0
# ES     3
# FR     2
# GB     6
# GR     3
# HN     1
# HR     0
# HU     0
# IE     0
# IL     0
# IN     4
# IQ     0
# IR     0
# IT     0
# JP     0
# KE     1
# LU     1
# MD     0
# MT     0
# MX     0
# MY     0
# NG     1
# NL     0
# NZ     0
# PK     1
# PL     0
# PT     0
# RO     0
# RU     0
# SG     0
# SI     0
# TR     0
# UA     0
# US    83
# VN     0
# Name: job_title, dtype: int64

# %%
filt=df["company_location"]=="DE"
df2 = df.loc[filt].copy()

# %%
df2.sort_values(by=["job_title","salary_in_usd"], ascending=[True, False])
# Out:
#      work_year experience_level employment_type  \
# 261       2021               SE              FT
# 80        2021               SE              FT
# 269       2021               EN              FT
# 496       2022               EN              FT
# 462       2022               MI              PT
# 53        2020               EN              FT
# 30        2020               MI              FT
# 91        2021               EN              FT
# 272       2021               EN              FT
# 163       2021               EN              FT
# 181       2021               MI              FT
# 217       2021               MI              FT
# 227       2021               MI              FT
# 0         2020               MI              FT
# 65        2020               EN              FT
# 66        2020               EN              FT
# 264       2021               MI              FT
# 259       2021               EX              FT
# ...

# %%
df2.plot.barh(x="job_title",y="salary_in_usd",rot=0, title="Ein erster Überblick")
# Out:
# <Axes: title={'center': 'Ein erster Überblick'}, ylabel='job_title'>

# %%
df2["job_title"].value_counts()
# Out:
# Data Scientist                    7
# Data Engineer                     4
# Machine Learning Engineer         4
# Principal Data Scientist          3
# Data Science Consultant           3
# Director of Data Science          2
# Data Engineering Manager          1
# ML Engineer                       1
# Data Analytics Engineer           1
# Data Analyst                      1
# Lead Machine Learning Engineer    1
# Name: job_title, dtype: int64

# %%
df2.sort_values(by= "experience_level", ascending=True)
# Out:
#      work_year experience_level employment_type  \
# 214       2021               EN              FT
# 273       2021               EN              FT
# 272       2021               EN              FT
# 269       2021               EN              FT
# 163       2021               EN              FT
# 91        2021               EN              FT
# 496       2022               EN              FT
# 65        2020               EN              FT
# 45        2020               EN              PT
# 53        2020               EN              FT
# 66        2020               EN              FT
# 259       2021               EX              FT
# 164       2021               EX              FT
# 462       2022               MI              PT
# 396       2022               MI              FT
# 30        2020               MI              FT
# 264       2021               MI              FT
# 0         2020               MI              FT
# ...

# %%
ax=df2["job_title"].value_counts().head(10).plot(kind="pie", title="Berufsverteilung - Deutschland")

# %%
pd.crosstab(df2.job_title, df2.work_year)
# Out:
# work_year                       2020  2021  2022
# job_title
# Data Analyst                       0     1     0
# Data Analytics Engineer            0     1     0
# Data Engineer                      1     1     2
# Data Engineering Manager           1     0     0
# Data Science Consultant            0     3     0
# Data Scientist                     3     4     0
# Director of Data Science           0     2     0
# Lead Machine Learning Engineer     0     0     1
# ML Engineer                        1     0     0
# Machine Learning Engineer          0     3     1
# Principal Data Scientist           1     1     1

# %%
sa=pd.pivot_table(data=df2,index='job_title', values='salary_in_usd', aggfunc="mean").round(2).plot.barh(title="Durchschnittlicher Verdienst in Deutschland")

# %% [markdown]
# ---------

# %% [markdown]
# # EIN NEUER VERSUCH

# %%
data2 = pd.read_csv("ds_salaries.csv")
data2.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data2.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
neu=data2[['work_year', 'experience_level', 'employment_type',
       'job_title', 'salary_in_usd' , 'salary_currency',
       'employee_residence', 'company_location',]]
neu.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary_in_usd salary_currency employee_residence company_location
# 0          79833             EUR                 DE               DE
# 1         260000             USD                 JP               JP
# 2         109024             GBP                 GB               GB
# 3          20000             USD                 HN               HN
# 4         150000             USD                 US               US

# %%
neu.sort_values("job_title").head(20)
# Out:
#      work_year experience_level employment_type  \
# 77        2021               MI              PT
# 606       2022               MI              FT
# 96        2021               EN              PT
# 113       2021               EN              PT
# 244       2021               EN              FT
# 52        2020               EN              FT
# 277       2021               SE              FT
# 391       2022               MI              FT
# 561       2022               SE              FT
# 560       2022               SE              FT
# 368       2022               EX              FT
# 344       2022               EX              FT
# 82        2021               MI              FT
# 123       2021               EN              FT
# 525       2022               SE              FT
# 519       2022               SE              FT
# 509       2022               MI              FT
# 157       2021               MI              FT
# ...

# %%
neu.groupby("job_title")["salary_in_usd"].mean().round(2).sort_values(ascending=False).head(35)
#.plot.barh()
# Out:
# job_title
# Data Analytics Lead                         405000.00
# Principal Data Engineer                     328333.33
# Financial Data Analyst                      275000.00
# Principal Data Scientist                    215242.43
# Director of Data Science                    195074.00
# Data Architect                              177873.91
# Applied Data Scientist                      175655.00
# Analytics Engineer                          175000.00
# Data Specialist                             165000.00
# Head of Data                                160162.60
# Machine Learning Scientist                  158412.50
# Data Science Manager                        158328.50
# Director of Data Engineering                156738.00
# Head of Data Science                        146718.75
# Applied Machine Learning Scientist          142068.75
# Lead Data Engineer                          139724.50
# Data Analytics Manager                      127134.29
# ...

# %%
ek1=neu.groupby("job_title")["salary_in_usd"].mean().round(2).sort_values(ascending=False).head(15).plot.barh(title="DATA-Berufsverteilung, weltweit", legend=False)
#.legend()

ek=(ek1)

# %%
exl=neu["experience_level"].value_counts().plot.barh(title="Experience_Level weltweit")
